# %%
# 사용할 패키지 불러오기
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# 먼저 자료에 대해 시간에 따른 분석을 적용하기 위해서는 unique한 영상에 대해서 다루는 게 아니라 수정되지 않은 자료로 분석을 진행해야 할 것 같아 데이터는 하나만 사용했습니다.

# %%
# 데이터 불러오기
df = pd.read_csv("C:/Users/김지희/DSL/dataset/youtube_0717.csv", lineterminator='\n')
df_uni = pd.read_csv("C:/Users/김지희/DSL/dataset/youtube_unique_0717.csv", lineterminator='\n')

# %%
# 데이터 관찰하기
df.head()
# Out:
#       video_id                                             title  \
# 0  uq5LClQN3cE                                       안녕하세요 보겸입니다
# 1  I-ZbZCHsHD0                                부락토스의 계획 [총몇명 프리퀄]
# 2  9d7jNUjBoss                                   평생 반성하면서 살겠습니다.
# 3  3pI_L3-sMVg                              안녕하세요 꽈뚜룹입니다.
# 4  zrsBjYukE8s  박진영 (J.Y. Park) When We Disco (Duet with 선미) M/V
#
#            publishedAt                 channelId       channelTitle  \
# 0  2020-08-09 09:32:48  UCu9BCtGIEr73LXZsKmoujKw              보겸 BK
# 1  2020-08-12 09:00:08  UCRuSxVu4iqTK5kCh90ntAgA                총몇명
# 2  2020-08-10 09:54:13  UCMVC92EOs9yDJG5JS-CMesQ        양팡 YangPang
# 3  2020-08-11 15:00:58  UCkQCwnkQfgSuPTTnw_Y7v7w      꽈뚜룹 Quaddurup
# 4  2020-08-11 09:00:13  UCaO6TYtlC8U5ttz62hTrZgg  JYP Entertainment
#
#          trending_date                                               tags  \
# 0  2020-08-12 00:00:00                                          보겸|bokyem
# 1  2020-08-12 00:00:00                총몇명|재밌는 만화|부락토스|루시퍼|총몇명 프리퀄|총몇명 스토리
# 2  2020-08-12 00:00:00  양팡|양팡유튜브|팡튜브|가족시트콤|양팡가족|양팡가족시트콤|양팡언니|현실남매|현실자매...
# 3  2020-08-12 00:00:00  꽈뚜룹|한국여행기|quaddurup|뚜룹이|korea|southkorea|vlog|...
# 4  2020-08-12 00:00:00  JYP Entertainment|JYP|J.Y.Park|JYPark|박진영|선미|S...
#
#    view_count   likes  dislikes  comment_count  comments_disabled  \
# 0     5947503   53326    105756         139946              False
# 1      963384   28244       494           3339              False
# 2     2950885   17974     68898          50688              False
# 3     1743374   36893      1798           8751              False
# 4     3433885  353337      9763          23405              False
#
#    ratings_disabled                                        description  \
# 0             False                                                NaN
# 1             False  오늘도 정말 감사드립니다!!총몇명 스튜디오 - 총몇명, 십제곱, 5G민, MOVE혁...
# 2             False                                                NaN
# 3             False                앞으로 좀 더 깔끔한 영상제작 약속 드리겠습니다.늘 감사드립니다
# 4             False  MelOn http://kko.to/TWyXd7zYjSpotify https://s...
#
#       category_name  tag_num
# 0     Entertainment        2
# 1  Film & Animation        6
# 2    People & Blogs       27
# 3     Entertainment       12
# 4             Music       13

# %%
# 데이터셋에 날짜가 object 형태로 나와있어서 다시 datetime 형태로 변형
df['publishedAt'] = pd.to_datetime(df['publishedAt'], format='%Y-%m-%d %H:%M:%S')
df_uni['publishedAt'] = pd.to_datetime(df_uni['publishedAt'], format='%Y-%m-%d %H:%M:%S')


df['trending_date'] = pd.to_datetime(df['trending_date'], format='%Y-%m-%d 00:00:00')
df_uni['trending_date'] = pd.to_datetime(df_uni['trending_date'], format='%Y-%m-%d 00:00:00')

# %%
# datetime의 경우 weekday라는 method를 제공해서 요일을 반환해줌
df['trending_date'][2].weekday()
# Out:
# 2

# %%
# 요일로 변경한 열 생성
df['trend_day'] = df['trending_date'].dt.day_name()
df['trend_day'] = df['trend_day'].astype('category')

# %%
df['trend_day']
# Out:
# 0         Wednesday
# 1         Wednesday
# 2         Wednesday
# 3         Wednesday
# 4         Wednesday
#             ...
# 137536       Monday
# 137537       Monday
# 137538       Monday
# 137539       Monday
# 137540       Monday
# Name: trend_day, Length: 137541, dtype: category
# Categories (7, object): ['Friday', 'Monday', 'Saturday', 'Sunday', 'Thursday', 'Tuesday', 'Wednesday']

# %%
# 월로 변경한 열 생성
df['trend_mon'] = df['trending_date'].dt.month
df['trend_mon'] = df['trend_mon'].astype('category')

# %%
df.head()
# Out:
#       video_id                                             title  \
# 0  uq5LClQN3cE                                       안녕하세요 보겸입니다
# 1  I-ZbZCHsHD0                                부락토스의 계획 [총몇명 프리퀄]
# 2  9d7jNUjBoss                                   평생 반성하면서 살겠습니다.
# 3  3pI_L3-sMVg                              안녕하세요 꽈뚜룹입니다.
# 4  zrsBjYukE8s  박진영 (J.Y. Park) When We Disco (Duet with 선미) M/V
#
#            publishedAt                 channelId       channelTitle  \
# 0  2020-08-09 09:32:48  UCu9BCtGIEr73LXZsKmoujKw              보겸 BK
# 1  2020-08-12 09:00:08  UCRuSxVu4iqTK5kCh90ntAgA                총몇명
# 2  2020-08-10 09:54:13  UCMVC92EOs9yDJG5JS-CMesQ        양팡 YangPang
# 3  2020-08-11 15:00:58  UCkQCwnkQfgSuPTTnw_Y7v7w      꽈뚜룹 Quaddurup
# 4  2020-08-11 09:00:13  UCaO6TYtlC8U5ttz62hTrZgg  JYP Entertainment
#
#   trending_date                                               tags  \
# 0    2020-08-12                                          보겸|bokyem
# 1    2020-08-12                총몇명|재밌는 만화|부락토스|루시퍼|총몇명 프리퀄|총몇명 스토리
# 2    2020-08-12  양팡|양팡유튜브|팡튜브|가족시트콤|양팡가족|양팡가족시트콤|양팡언니|현실남매|현실자매...
# 3    2020-08-12  꽈뚜룹|한국여행기|quaddurup|뚜룹이|korea|southkorea|vlog|...
# 4    2020-08-12  JYP Entertainment|JYP|J.Y.Park|JYPark|박진영|선미|S...
#
#    view_count   likes  dislikes  comment_count  comments_disabled  \
# 0     5947503   53326    105756         139946              False
# 1      963384   28244       494           3339              False
# 2     2950885   17974     68898          50688              False
# 3     1743374   36893      1798           8751              False
# 4     3433885  353337      9763          23405              False
#
#    ratings_disabled                                        description  \
# 0             False                                                NaN
# 1             False  오늘도 정말 감사드립니다!!총몇명 스튜디오 - 총몇명, 십제곱, 5G민, MOVE혁...
# 2             False                                                NaN
# 3             False                앞으로 좀 더 깔끔한 영상제작 약속 드리겠습니다.늘 감사드립니다
# 4             False  MelOn http://kko.to/TWyXd7zYjSpotify https://s...
#
#       category_name  tag_num  trend_day trend_mon
# 0     Entertainment        2  Wednesday         8
# 1  Film & Animation        6  Wednesday         8
# 2    People & Blogs       27  Wednesday         8
# 3     Entertainment       12  Wednesday         8
# 4             Music       13  Wednesday         8

# %%
print('요일 평균 카테고리별 트렌딩 영상 수: ', end='')
print(df.query('trending_date.dt.dayofweek in [0,1,2,3,4,5,6]')['category_name'].value_counts().sum(),"개")
mean_count = df.query('trending_date.dt.dayofweek in [0,1,2,3,4,5,6]')['category_name'].value_counts()
print(mean_count)

print('-'*30)
print("월요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): ", end='')
print(df.query('trending_date.dt.dayofweek == 0')['category_name'].value_counts().sum(),"개")
print((df.query('trending_date.dt.dayofweek == 0')['category_name'].value_counts()-mean_count))

print('-'*30)
print("화요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): ", end='')
print(df.query('trending_date.dt.dayofweek == 1')['category_name'].value_counts().sum(),"개")
print((df.query('trending_date.dt.dayofweek == 1')['category_name'].value_counts()-mean_count))

print('-'*30)
print("수요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): ", end='')
print(df.query('trending_date.dt.dayofweek == 2')['category_name'].value_counts().sum(),"개")
print((df.query('trending_date.dt.dayofweek == 2')['category_name'].value_counts()-mean_count))

print('-'*30)
print("목요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): ", end='')
print(df.query('trending_date.dt.dayofweek == 3')['category_name'].value_counts().sum(),"개")
print((df.query('trending_date.dt.dayofweek == 3')['category_name'].value_counts()-mean_count))

print('-'*30)
print("금요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): ", end='')
print(df.query('trending_date.dt.dayofweek == 4')['category_name'].value_counts().sum(),"개")
print((df.query('trending_date.dt.dayofweek == 4')['category_name'].value_counts()-mean_count))

print('-'*30)
print("토요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): ", end='')
print(df.query('trending_date.dt.dayofweek == 5')['category_name'].value_counts().sum(),"개")
print((df.query('trending_date.dt.dayofweek == 5')['category_name'].value_counts()-mean_count))

print('-'*30)
print("일요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): ", end='')
print(df.query('trending_date.dt.dayofweek == 6')['category_name'].value_counts().sum(),"개")
print((df.query('trending_date.dt.dayofweek == 6')['category_name'].value_counts()-mean_count))


# 미세한 영상의 개수차이만 존재할 뿐 trending된 영상의 카테고리별 순위에 대해서는 전체적으로 유의미한 차이를 보이지는 않음
# Out:
# 요일 평균 카테고리별 트렌딩 영상 수: 137541 개
# Entertainment            47874
# People & Blogs           21699
# Music                    14787
# Sports                   10544
# Comedy                    8626
# News & Politics           6795
# Howto & Style             5972
# Gaming                    5085
# Film & Animation          4469
# Pets & Animals            2793
# Education                 2691
# Science & Technology      2293
# Travel & Events           1966
# Autos & Vehicles          1708
# Nonprofits & Activism      239
# Name: category_name, dtype: int64
# ------------------------------
# 월요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): 19989 개
# Entertainment           -40854
# People & Blogs          -18528
# Music                   -12704
# Sports                   -8971
# Comedy                   -7361
# News & Politics          -5839
# Howto & Style            -5128
# Gaming                   -4355
# Film & Animation         -3802
# Pets & Animals           -2384
# Education                -2290
# Science & Technology     -1971
# Travel & Events          -1677
# Autos & Vehicles         -1477
# Nonprofits & Activism     -211
# Name: category_name, dtype: int64
# ------------------------------
# 화요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): 19690 개
# Entertainment           -41041
# People & Blogs          -18592
# Music                   -12631
# Sports                   -8965
# Comedy                   -7418
# News & Politics          -5828
# Howto & Style            -5104
# Gaming                   -4372
# Film & Animation         -3834
# Pets & Animals           -2397
# Education                -2310
# Science & Technology     -1986
# Travel & Events          -1695
# Autos & Vehicles         -1468
# Nonprofits & Activism     -210
# Name: category_name, dtype: int64
# ------------------------------
# 수요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): 19784 개
# Autos & Vehicles         -1447
# Comedy                   -7427
# Education                -2282
# Entertainment           -41074
# Film & Animation         -3863
# Gaming                   -4339
# Howto & Style            -5109
# Music                   -12587
# News & Politics          -5776
# Nonprofits & Activism     -203
# People & Blogs          -18594
# Pets & Animals           -2409
# Science & Technology     -1968
# Sports                   -8991
# Travel & Events          -1688
# Name: category_name, dtype: int64
# ------------------------------
# 목요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): 19980 개
# Entertainment           -41116
# People & Blogs          -18529
# Music                   -12591
# Sports                   -8985
# Comedy                   -7399
# News & Politics          -5743
# Howto & Style            -5091
# Gaming                   -4344
# Film & Animation         -3821
# Pets & Animals           -2389
# Education                -2288
# Science & Technology     -1947
# Travel & Events          -1671
# Autos & Vehicles         -1449
# Nonprofits & Activism     -198
# Name: category_name, dtype: int64
# ------------------------------
# 금요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): 19555 개
# Entertainment           -41063
# People & Blogs          -18615
# Music                   -12677
# Sports                   -9070
# Comedy                   -7360
# News & Politics          -5827
# Howto & Style            -5117
# Gaming                   -4361
# Film & Animation         -3859
# Pets & Animals           -2410
# Education                -2327
# Science & Technology     -1961
# Travel & Events          -1680
# Autos & Vehicles         -1455
# Nonprofits & Activism     -204
# Name: category_name, dtype: int64
# ------------------------------
# 토요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): 19392 개
# Entertainment           -40997
# People & Blogs          -18640
# Music                   -12745
# Sports                   -9157
# Comedy                   -7380
# News & Politics          -5870
# Howto & Style            -5130
# Gaming                   -4367
# Film & Animation         -3826
# Pets & Animals           -2397
# Education                -2328
# Science & Technology     -1953
# Travel & Events          -1694
# Autos & Vehicles         -1463
# Nonprofits & Activism     -202
# Name: category_name, dtype: int64
# ------------------------------
# 일요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): 19151 개
# Entertainment           -41099
# People & Blogs          -18696
# Music                   -12787
# Sports                   -9125
# Comedy                   -7411
# News & Politics          -5887
# Howto & Style            -5153
# Gaming                   -4372
# Film & Animation         -3809
# Pets & Animals           -2372
# Education                -2321
# Science & Technology     -1972
# Travel & Events          -1691
# Autos & Vehicles         -1489
# Nonprofits & Activism     -206
# Name: category_name, dtype: int64

# %%
print('요일 평균 카테고리별 트렌딩 영상 수: ', end='')
print(df.query('trending_date.dt.dayofweek in [0,1,2,3,4,5,6]')['category_name'].value_counts().sum(),"개")
mean_count = df.query('trending_date.dt.dayofweek in [0,1,2,3,4,5,6]')['category_name'].value_counts()/7
print(mean_count)

print('-'*30)
print("월요일 카테고리별 트렌딩 영상 수 차이(평균과 비교: ", end='')
print(df.query('trending_date.dt.dayofweek == 0')['category_name'].value_counts().sum(),"개")
print((df.query('trending_date.dt.dayofweek == 0')['category_name'].value_counts()-mean_count)>0)

print('-'*30)
print("화요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): ", end='')
print(df.query('trending_date.dt.dayofweek == 1')['category_name'].value_counts().sum(),"개")
print((df.query('trending_date.dt.dayofweek == 1')['category_name'].value_counts()-mean_count)>0)

print('-'*30)
print("수요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): ", end='')
print(df.query('trending_date.dt.dayofweek == 2')['category_name'].value_counts().sum(),"개")
print((df.query('trending_date.dt.dayofweek == 2')['category_name'].value_counts()-mean_count)>0)

print('-'*30)
print("목요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): ", end='')
print(df.query('trending_date.dt.dayofweek == 3')['category_name'].value_counts().sum(),"개")
print((df.query('trending_date.dt.dayofweek == 3')['category_name'].value_counts()-mean_count)>0)

print('-'*30)
print("금요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): ", end='')
print(df.query('trending_date.dt.dayofweek == 4')['category_name'].value_counts().sum(),"개")
print((df.query('trending_date.dt.dayofweek == 4')['category_name'].value_counts()-mean_count)>0)

print('-'*30)
print("토요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): ", end='')
print(df.query('trending_date.dt.dayofweek == 5')['category_name'].value_counts().sum(),"개")
print((df.query('trending_date.dt.dayofweek == 5')['category_name'].value_counts()-mean_count)>0)

print('-'*30)
print("일요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): ", end='')
print(df.query('trending_date.dt.dayofweek == 6')['category_name'].value_counts().sum(),"개")
print((df.query('trending_date.dt.dayofweek == 6')['category_name'].value_counts()-mean_count)>0)


# 미세한 영상의 개수차이만 존재할 뿐 trending된 영상의 카테고리별 순위에 대해서는 전체적으로 유의미한 차이를 보이지는 않음
# Out:
# 요일 평균 카테고리별 트렌딩 영상 수: 137541 개
# Entertainment            6839.142857
# People & Blogs           3099.857143
# Music                    2112.428571
# Sports                   1506.285714
# Comedy                   1232.285714
# News & Politics           970.714286
# Howto & Style             853.142857
# Gaming                    726.428571
# Film & Animation          638.428571
# Pets & Animals            399.000000
# Education                 384.428571
# Science & Technology      327.571429
# Travel & Events           280.857143
# Autos & Vehicles          244.000000
# Nonprofits & Activism      34.142857
# Name: category_name, dtype: float64
# ------------------------------
# 월요일 카테고리별 트렌딩 영상 수 차이(평균과 비교: 19989 개
# Entertainment             True
# People & Blogs            True
# Music                    False
# Sports                    True
# Comedy                    True
# News & Politics          False
# Howto & Style            False
# Gaming                    True
# Film & Animation          True
# Pets & Animals            True
# Education                 True
# Science & Technology     False
# Travel & Events           True
# Autos & Vehicles         False
# Nonprofits & Activism    False
# Name: category_name, dtype: bool
# ------------------------------
# 화요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): 19690 개
# Entertainment            False
# People & Blogs            True
# Music                     True
# Sports                    True
# Comedy                   False
# News & Politics          False
# Howto & Style             True
# Gaming                   False
# Film & Animation         False
# Pets & Animals           False
# Education                False
# Science & Technology     False
# Travel & Events          False
# Autos & Vehicles         False
# Nonprofits & Activism    False
# Name: category_name, dtype: bool
# ------------------------------
# 수요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): 19784 개
# Autos & Vehicles          True
# Comedy                   False
# Education                 True
# Entertainment            False
# Film & Animation         False
# Gaming                    True
# Howto & Style             True
# Music                     True
# News & Politics           True
# Nonprofits & Activism     True
# People & Blogs            True
# Pets & Animals           False
# Science & Technology     False
# Sports                    True
# Travel & Events          False
# Name: category_name, dtype: bool
# ------------------------------
# 목요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): 19980 개
# Entertainment            False
# People & Blogs            True
# Music                     True
# Sports                    True
# Comedy                   False
# News & Politics           True
# Howto & Style             True
# Gaming                    True
# Film & Animation          True
# Pets & Animals            True
# Education                 True
# Science & Technology      True
# Travel & Events           True
# Autos & Vehicles          True
# Nonprofits & Activism     True
# Name: category_name, dtype: bool
# ------------------------------
# 금요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): 19555 개
# Entertainment            False
# People & Blogs           False
# Music                    False
# Sports                   False
# Comedy                    True
# News & Politics          False
# Howto & Style             True
# Gaming                   False
# Film & Animation         False
# Pets & Animals           False
# Education                False
# Science & Technology      True
# Travel & Events           True
# Autos & Vehicles          True
# Nonprofits & Activism     True
# Name: category_name, dtype: bool
# ------------------------------
# 토요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): 19392 개
# Entertainment             True
# People & Blogs           False
# Music                    False
# Sports                   False
# Comedy                    True
# News & Politics          False
# Howto & Style            False
# Gaming                   False
# Film & Animation          True
# Pets & Animals           False
# Education                False
# Science & Technology      True
# Travel & Events          False
# Autos & Vehicles          True
# Nonprofits & Activism     True
# Name: category_name, dtype: bool
# ------------------------------
# 일요일 카테고리별 트렌딩 영상 수 차이(평균과 비교): 19151 개
# Entertainment            False
# People & Blogs           False
# Music                    False
# Sports                   False
# Comedy                   False
# News & Politics          False
# Howto & Style            False
# Gaming                   False
# Film & Animation          True
# Pets & Animals            True
# Education                False
# Science & Technology     False
# Travel & Events          False
# Autos & Vehicles         False
# Nonprofits & Activism    False
# Name: category_name, dtype: bool

# %%
week_day = df.query('trending_date.dt.dayofweek in [0,1,2,3,4]')
week_end = df.query('trending_date.dt.dayofweek in [5,6]')

# %%
print("주중 카테고리별 평균 트렌딩 영상 수: ", end='')
print(week_day['category_name'].value_counts().sum()/5)
print(week_day['category_name'].value_counts()/5)

print('-'*30)

print("주말 카테고리별 평균 트렌딩 영상 수: ", end='')
print(week_end['category_name'].value_counts().sum()/2)
print(week_end['category_name'].value_counts()/2)

# 미세한 영상의 개수차이만 존재할 뿐 trending된 영상의 카테고리별 순위에 대해서는 전체적으로 유의미한 차이를 보이지는 않음

# %%
print("주중 카테고리별 트렌딩 영상 수")
print(week_day['category_name'].value_counts()/5)

print('-'*30)

print("주말 카테고리별 트렌딩 영상 수")
print(week_end['category_name'].value_counts()/2)

# 미세한 영상의 개수차이만 존재할 뿐 trending된 영상의 카테고리별 순위에 대해서는 전체적으로 유의미한 차이를 보이지는 않음
# Out:
# 주중 카테고리별 트렌딩 영상 수
# Entertainment            6844.4
# People & Blogs           3127.4
# Music                    2149.0
# Sports                   1547.6
# Comedy                   1233.0
# News & Politics           992.4
# Howto & Style             862.2
# Gaming                    730.8
# Film & Animation          633.2
# Pets & Animals            395.2
# Education                 391.6
# Science & Technology      326.4
# Travel & Events           283.8
# Autos & Vehicles          248.8
# Nonprofits & Activism      33.8
# Name: category_name, dtype: float64
# ------------------------------
# 주말 카테고리별 트렌딩 영상 수
# Entertainment            6826.0
# People & Blogs           3031.0
# Music                    2021.0
# Sports                   1403.0
# Comedy                   1230.5
# News & Politics           916.5
# Howto & Style             830.5
# Gaming                    715.5
# Film & Animation          651.5
# Pets & Animals            408.5
# Education                 366.5
# Science & Technology      330.5
# Travel & Events           273.5
# Autos & Vehicles          232.0
# Nonprofits & Activism      35.0
# Name: category_name, dtype: float64

# %%
print("겨울 카테고리별 트렌딩 영상 수: ", end='')
print(df.query('trending_date.dt.month in [12,1,2]')['category_name'].value_counts().sum(),"개")
print(df.query('trending_date.dt.month in [12,1,2]')['category_name'].value_counts().apply(prob))

print('-'*30)
print("봄 카테고리별 트렌딩 영상 수: ", end='')
print(df.query('trending_date.dt.month in [3,4,5]')['category_name'].value_counts().sum(),"개")
print(df.query('trending_date.dt.month in [3,4,5]')['category_name'].value_counts())

print('-'*30)
print("여름 카테고리별 트렌딩 영상 수: ", end='')
print(df.query('trending_date.dt.month in [6,7,8]')['category_name'].value_counts().sum(),"개")
print(df.query('trending_date.dt.month in [6,7,8]')['category_name'].value_counts())

print('-'*30)
print("가을 카테고리별 트렌딩 영상 수: ", end='')
print(df.query('trending_date.dt.month in [9,10,11]')['category_name'].value_counts().sum(),"개")
print(df.query('trending_date.dt.month in [9,10,11]')['category_name'].value_counts())

# 미세한 영상의 개수차이만 존재할 뿐 trending된 영상의 카테고리별 순위에 대해서는 전체적으로 유의미한 차이를 보이지는 않음
# Out:
# 겨울 카테고리별 트렌딩 영상 수: 35193 개
# Entertainment            12366
# People & Blogs            5657
# Music                     3269
# Sports                    2776
# Comedy                    2401
# Howto & Style             1643
# Gaming                    1423
# News & Politics           1322
# Film & Animation          1040
# Education                  898
# Pets & Animals             716
# Travel & Events            587
# Science & Technology       499
# Autos & Vehicles           493
# Nonprofits & Activism      103
# Name: category_name, dtype: int64
# ------------------------------
# 봄 카테고리별 트렌딩 영상 수: 35993 개
# Entertainment            13142
# People & Blogs            5519
# Music                     4028
# Sports                    2734
# Comedy                    2699
# News & Politics           1848
# Howto & Style             1536
# Gaming                    1169
# Film & Animation          1039
# Education                  567
# Pets & Animals             561
# Travel & Events            491
# Autos & Vehicles           357
# Science & Technology       270
# Nonprofits & Activism       33
# Name: category_name, dtype: int64
# ------------------------------
# 여름 카테고리별 트렌딩 영상 수: 32346 개
# Entertainment            11008
# People & Blogs            5333
# Music                     3396
# Sports                    2470
# Comedy                    1821
# News & Politics           1804
# Howto & Style             1298
# Gaming                    1247
# Film & Animation           994
# Pets & Animals             890
# Science & Technology       636
# Education                  575
# Travel & Events            462
# Autos & Vehicles           377
# Nonprofits & Activism       35
# Name: category_name, dtype: int64
# ------------------------------
# 가을 카테고리별 트렌딩 영상 수: 34009 개
# Entertainment            11358
# People & Blogs            5190
# Music                     4094
# Sports                    2564
# News & Politics           1821
# Comedy                    1705
# Howto & Style             1495
# Film & Animation          1396
# Gaming                    1246
# Science & Technology       888
# Education                  651
# Pets & Animals             626
# Autos & Vehicles           481
# Travel & Events            426
# Nonprofits & Activism       68
# Name: category_name, dtype: int64

# %%
print("겨울 카테고리별 unique한 트렌딩 영상 수: ", end='')
print(df_uni.query('trending_date.dt.month in [12,1,2]')['category_name'].value_counts().sum(),"개")
print(df_uni.query('trending_date.dt.month in [12,1,2]')['category_name'].value_counts())

print('-'*30)
print("봄 카테고리별 unique한 트렌딩 영상 수: ", end='')
print(df_uni.query('trending_date.dt.month in [3,4,5]')['category_name'].value_counts().sum(),"개")
print(df_uni.query('trending_date.dt.month in [3,4,5]')['category_name'].value_counts())

print('-'*30)
print("여름 카테고리별 unique한 트렌딩 영상 수: ", end='')
print(df_uni.query('trending_date.dt.month in [6,7,8]')['category_name'].value_counts().sum(),"개")
print(df_uni.query('trending_date.dt.month in [6,7,8]')['category_name'].value_counts())

print('-'*30)
print("가을 카테고리별 unique한 트렌딩 영상 수: ", end='')
print(df_uni.query('trending_date.dt.month in [9,10,11]')['category_name'].value_counts().sum(),"개")
print(df_uni.query('trending_date.dt.month in [9,10,11]')['category_name'].value_counts())

# 미세한 영상의 개수차이만 존재할 뿐 trending된 영상의 카테고리별 순위에 대해서는 전체적으로 유의미한 차이를 보이지는 않음
# Out:
# 겨울 카테고리별 unique한 트렌딩 영상 수: 4243 개
# Entertainment            1514
# People & Blogs            671
# Music                     399
# Sports                    353
# Comedy                    269
# Howto & Style             181
# News & Politics           167
# Gaming                    165
# Film & Animation          134
# Education                 111
# Pets & Animals             88
# Travel & Events            65
# Science & Technology       62
# Autos & Vehicles           51
# Nonprofits & Activism      13
# Name: category_name, dtype: int64
# ------------------------------
# 봄 카테고리별 unique한 트렌딩 영상 수: 4120 개
# Entertainment            1512
# People & Blogs            610
# Music                     477
# Sports                    332
# Comedy                    296
# News & Politics           238
# Howto & Style             164
# Gaming                    131
# Film & Animation          107
# Education                  66
# Pets & Animals             58
# Travel & Events            53
# Autos & Vehicles           43
# Science & Technology       29
# Nonprofits & Activism       4
# Name: category_name, dtype: int64
# ------------------------------
# 여름 카테고리별 unique한 트렌딩 영상 수: 3778 개
# Entertainment            1258
# People & Blogs            582
# Music                     401
# Sports                    325
# News & Politics           287
# Comedy                    190
# Gaming                    157
# Howto & Style             126
# Film & Animation          122
# Pets & Animals             96
# Science & Technology       68
# Education                  66
# Travel & Events            53
# Autos & Vehicles           42
# Nonprofits & Activism       5
# Name: category_name, dtype: int64
# ------------------------------
# 가을 카테고리별 unique한 트렌딩 영상 수: 4787 개
# Entertainment            1535
# People & Blogs            665
# Music                     552
# News & Politics           412
# Sports                    410
# Comedy                    229
# Film & Animation          194
# Gaming                    182
# Howto & Style             172
# Science & Technology      133
# Education                  96
# Pets & Animals             80
# Autos & Vehicles           70
# Travel & Events            47
# Nonprofits & Activism      10
# Name: category_name, dtype: int64

# %%
(df['trending_date']-df['publishedAt'])[days]
# Out:
# 0          2 days 14:27:12
# 1        -1 days +14:59:52
# 2          1 days 14:05:47
# 3          0 days 08:59:02
# 4          0 days 14:59:47
#                 ...
# 137536    13 days 11:57:47
# 137537    12 days 00:59:29
# 137538    13 days 12:00:00
# 137539    13 days 15:01:50
# 137540    11 days 16:59:51
# Length: 137541, dtype: timedelta64[ns]

# %%
df.head()
# Out:
#       video_id                                             title  \
# 0  uq5LClQN3cE                                       안녕하세요 보겸입니다
# 1  I-ZbZCHsHD0                                부락토스의 계획 [총몇명 프리퀄]
# 2  9d7jNUjBoss                                   평생 반성하면서 살겠습니다.
# 3  3pI_L3-sMVg                              안녕하세요 꽈뚜룹입니다.
# 4  zrsBjYukE8s  박진영 (J.Y. Park) When We Disco (Duet with 선미) M/V
#
#           publishedAt                 channelId       channelTitle  \
# 0 2020-08-09 09:32:48  UCu9BCtGIEr73LXZsKmoujKw              보겸 BK
# 1 2020-08-12 09:00:08  UCRuSxVu4iqTK5kCh90ntAgA                총몇명
# 2 2020-08-10 09:54:13  UCMVC92EOs9yDJG5JS-CMesQ        양팡 YangPang
# 3 2020-08-11 15:00:58  UCkQCwnkQfgSuPTTnw_Y7v7w      꽈뚜룹 Quaddurup
# 4 2020-08-11 09:00:13  UCaO6TYtlC8U5ttz62hTrZgg  JYP Entertainment
#
#   trending_date                                               tags  \
# 0    2020-08-12                                          보겸|bokyem
# 1    2020-08-12                총몇명|재밌는 만화|부락토스|루시퍼|총몇명 프리퀄|총몇명 스토리
# 2    2020-08-12  양팡|양팡유튜브|팡튜브|가족시트콤|양팡가족|양팡가족시트콤|양팡언니|현실남매|현실자매...
# 3    2020-08-12  꽈뚜룹|한국여행기|quaddurup|뚜룹이|korea|southkorea|vlog|...
# 4    2020-08-12  JYP Entertainment|JYP|J.Y.Park|JYPark|박진영|선미|S...
#
#    view_count   likes  dislikes  comment_count  comments_disabled  \
# 0     5947503   53326    105756         139946              False
# 1      963384   28244       494           3339              False
# 2     2950885   17974     68898          50688              False
# 3     1743374   36893      1798           8751              False
# 4     3433885  353337      9763          23405              False
#
#    ratings_disabled                                        description  \
# 0             False                                                NaN
# 1             False  오늘도 정말 감사드립니다!!총몇명 스튜디오 - 총몇명, 십제곱, 5G민, MOVE혁...
# 2             False                                                NaN
# 3             False                앞으로 좀 더 깔끔한 영상제작 약속 드리겠습니다.늘 감사드립니다
# 4             False  MelOn http://kko.to/TWyXd7zYjSpotify https://s...
#
#       category_name  tag_num
# 0     Entertainment        2
# 1  Film & Animation        6
# 2    People & Blogs       27
# 3     Entertainment       12
# 4             Music       13
