# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
Train=pd.read_csv('C:\\Users\\ADMIN\\Documents\\train.csv')
Train
# Out:
#        index gender car reality  child_num  income_total  \
# 0          0      F   N       N          0      202500.0
# 1          1      F   N       Y          1      247500.0
# 2          2      M   Y       Y          0      450000.0
# 3          3      F   N       Y          0      202500.0
# 4          4      F   Y       Y          0      157500.0
# ...      ...    ...  ..     ...        ...           ...
# 26452  26452      F   N       N          2      225000.0
# 26453  26453      F   N       Y          1      180000.0
# 26454  26454      F   Y       N          0      292500.0
# 26455  26455      M   N       Y          0      171000.0
# 26456  26456      F   N       N          0       81000.0
#
#                 income_type                       edu_type  \
# 0      Commercial associate               Higher education
# 1      Commercial associate  Secondary / secondary special
# 2                   Working               Higher education
# ...

# %%
Train.describe(include='all')
# Out:
#                index gender    car reality     child_num  income_total  \
# count   26457.000000  26457  26457   26457  26457.000000  2.645700e+04
# unique           NaN      2      2       2           NaN           NaN
# top              NaN      F      N       Y           NaN           NaN
# freq             NaN  17697  16410   17830           NaN           NaN
# mean    13228.000000    NaN    NaN     NaN      0.428658  1.873065e+05
# std      7637.622372    NaN    NaN     NaN      0.747326  1.018784e+05
# min         0.000000    NaN    NaN     NaN      0.000000  2.700000e+04
# 25%      6614.000000    NaN    NaN     NaN      0.000000  1.215000e+05
# 50%     13228.000000    NaN    NaN     NaN      0.000000  1.575000e+05
# 75%     19842.000000    NaN    NaN     NaN      1.000000  2.250000e+05
# max     26456.000000    NaN    NaN     NaN     19.000000  1.575000e+06
#
#        income_type                       edu_type family_type  \
# ...

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          26457 non-null  int64
#  1   gender         26457 non-null  object
#  2   car            26457 non-null  object
#  3   reality        26457 non-null  object
#  4   child_num      26457 non-null  int64
#  5   income_total   26457 non-null  float64
#  6   income_type    26457 non-null  object
#  7   edu_type       26457 non-null  object
#  8   family_type    26457 non-null  object
#  9   house_type     26457 non-null  object
#  10  DAYS_BIRTH     26457 non-null  int64
#  11  DAYS_EMPLOYED  26457 non-null  int64
#  12  FLAG_MOBIL     26457 non-null  int64
#  13  work_phone     26457 non-null  int64
#  14  phone          26457 non-null  int64
#  15  email          26457 non-null  int64
#  16  occyp_type     18286 non-null  object
# ...

# %%
Train.dtypes
# Out:
# index              int64
# gender            object
# car               object
# reality           object
# child_num          int64
# income_total     float64
# income_type       object
# edu_type          object
# family_type       object
# house_type        object
# DAYS_BIRTH         int64
# DAYS_EMPLOYED      int64
# FLAG_MOBIL         int64
# work_phone         int64
# phone              int64
# email              int64
# occyp_type        object
# family_size      float64
# begin_month      float64
# credit           float64
# dtype: object

# %%
def pltpie(label, sample):
    data = Train[Train[label] == sample]
    data_c = data['credit'].value_counts()
    data_c
    plt.pie(x=data_c, labels=data_c.index, autopct='%1.1f%%')
    plt.title(label+'_'+str(sample))
    plt.show()

# %%
 pltpie('family_type', 'Married')

# %%
 pltpie('family_type', 'Single / not married')

# %%
pltpie('family_type', 'Widow')

# %%
pltpie('family_type', 'Separated')

# %%
#결혼을 아직 하지 않았거나 사별한 사람들의 credit이 상대적으로 양호하다? 혼자 사는 사람들의 지출이 적기 때문?
#이혼하거나 결혼을 한 사람들은 credit이 상대적으로 낮음. 이혼한 사람은 혼자 삶에도 불구하고 credit이 낮은 이유는 이혼 중 발생하는 여러 지출?양육비?
#결혼을 한 사람들은 가족을 부양하는데 많은 비용이 듬.

# %%
  pltpie('house_type', 'House / apartment')

# %%
  pltpie('house_type', 'Rented apartment')

# %%
  pltpie('house_type', 'Municipal apartment')

# %%
pltpie('house_type', 'With parents')

# %%
#렌트 아파트에 사는 사람들의 credit 이 다른 house type에 거주 하는 사람들과 비교하여 크게 양호함. 이제 막 독립한 사회 초년생들이 사는 곳? 
#지방에서 일 하로 올라오는 사람들이 머무르는 곳? 요즘들어 직장이나 학교가 가까운곳에 있는 공공임대 주택의 인기가 많아지고 있음
#즉 꾸준히 돈을 버는 사람들... 
#지출이 다른 house type보다 적음 --> 주거비 절감, 종부세, 유지 관리비 없음

# %%
#family_type 과 house_type 에서 유의미한 차이 발견?

# %%
#결혼여부가 지출(신용수요)을 결정 
#거주지가 소득을 결정

# %%
Train2=Train[(Train['family_type']=='Single / not married')&(Train['house_type']=='Rented apartment')]

df=Train2.drop(['gender','reality','index','car','child_num','income_type','edu_type','DAYS_BIRTH','DAYS_EMPLOYED','FLAG_MOBIL','work_phone','phone','email','occyp_type','family_size','begin_month'], axis = 1)
df
# Out:
#        income_total           family_type        house_type  credit
# 130        297000.0  Single / not married  Rented apartment     0.0
# 177        157500.0  Single / not married  Rented apartment     1.0
# 205        171000.0  Single / not married  Rented apartment     2.0
# 228        292500.0  Single / not married  Rented apartment     0.0
# 647        297000.0  Single / not married  Rented apartment     1.0
# 717        297000.0  Single / not married  Rented apartment     0.0
# 888        297000.0  Single / not married  Rented apartment     0.0
# 1091       112500.0  Single / not married  Rented apartment     1.0
# 1275       180000.0  Single / not married  Rented apartment     1.0
# 1331       157500.0  Single / not married  Rented apartment     2.0
# 1533       171261.0  Single / not married  Rented apartment     2.0
# 1712       144000.0  Single / not married  Rented apartment     2.0
# 1981       540000.0  Single / not married  Rented apartment     2.0
# ...

# %%
print(df.mean())
# Out:
# income_total    228897.975524
# credit               1.342657
# dtype: float64
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20344\2807316344.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df.mean())

# %%
Train3=Train[(Train['family_type']=='Single / not married')&(Train['house_type']=='House / apartment')]

df1=Train3.drop(['gender','reality','index','car','child_num','income_type','edu_type','DAYS_BIRTH','DAYS_EMPLOYED','FLAG_MOBIL','work_phone','phone','email','occyp_type','family_size','begin_month'], axis = 1)
df1
# Out:
#        income_total           family_type         house_type  credit
# 14         157500.0  Single / not married  House / apartment     2.0
# 24         202500.0  Single / not married  House / apartment     2.0
# 36         225000.0  Single / not married  House / apartment     2.0
# 57         225000.0  Single / not married  House / apartment     1.0
# 70          81000.0  Single / not married  House / apartment     2.0
# ...             ...                   ...                ...     ...
# 26400      652500.0  Single / not married  House / apartment     2.0
# 26436      225000.0  Single / not married  House / apartment     2.0
# 26443       90000.0  Single / not married  House / apartment     1.0
# 26450      225000.0  Single / not married  House / apartment     2.0
# 26455      171000.0  Single / not married  House / apartment     2.0
#
# [2954 rows x 4 columns]

# %%
print(df1.mean())
# Out:
# income_total    192428.364760
# credit               1.496615
# dtype: float64
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20344\1183993460.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df1.mean())

# %%
Train4=Train[(Train['family_type']=='Married')&(Train['house_type']=='Rented apartment')]
df2=Train4.drop(['gender','reality','index','car','child_num','income_type','edu_type','DAYS_BIRTH','DAYS_EMPLOYED','FLAG_MOBIL','work_phone','phone','email','occyp_type','family_size','begin_month'], axis = 1)
df2
# Out:
#        income_total family_type        house_type  credit
# 179        315000.0     Married  Rented apartment     2.0
# 252         90000.0     Married  Rented apartment     1.0
# 356        234000.0     Married  Rented apartment     2.0
# 361        225000.0     Married  Rented apartment     1.0
# 518        112500.0     Married  Rented apartment     2.0
# ...             ...         ...               ...     ...
# 25848      157500.0     Married  Rented apartment     2.0
# 25967      135000.0     Married  Rented apartment     2.0
# 26083       90000.0     Married  Rented apartment     1.0
# 26369      292500.0     Married  Rented apartment     2.0
# 26414       40500.0     Married  Rented apartment     1.0
#
# [236 rows x 4 columns]

# %%
print(df2.mean())
# Out:
# income_total    206252.542373
# credit               1.478814
# dtype: float64
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20344\2250652926.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df2.mean())

# %%
Train5=Train[(Train['family_type']=='Married')&(Train['house_type']=='House / apartment')]
df3=Train2.drop(['gender','reality','index','car','child_num','income_type','edu_type','DAYS_BIRTH','DAYS_EMPLOYED','FLAG_MOBIL','work_phone','phone','email','occyp_type','family_size','begin_month'], axis = 1)
df3
# Out:
#        income_total           family_type        house_type  credit
# 130        297000.0  Single / not married  Rented apartment     0.0
# 177        157500.0  Single / not married  Rented apartment     1.0
# 205        171000.0  Single / not married  Rented apartment     2.0
# 228        292500.0  Single / not married  Rented apartment     0.0
# 647        297000.0  Single / not married  Rented apartment     1.0
# 717        297000.0  Single / not married  Rented apartment     0.0
# 888        297000.0  Single / not married  Rented apartment     0.0
# 1091       112500.0  Single / not married  Rented apartment     1.0
# 1275       180000.0  Single / not married  Rented apartment     1.0
# 1331       157500.0  Single / not married  Rented apartment     2.0
# 1533       171261.0  Single / not married  Rented apartment     2.0
# 1712       144000.0  Single / not married  Rented apartment     2.0
# 1981       540000.0  Single / not married  Rented apartment     2.0
# ...

# %%
print(df3.mean())
# Out:
# income_total    228897.975524
# credit               1.342657
# dtype: float64
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20344\392603381.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df3.mean())

# %%
#솔로이면서 임대 아파트에 사는 사람들의 평균 credit:1.34, 평균 income total:228897.98 --> 소득은 제일 높으면서 지출하는 금액은 제일 적은 사람들
#솔로이면선 아파트에 사는 사람들의 평균 credit:1.50, 평균 income total: 192428.36 
#결혼해서 임대 아파트에 사는 사람들의 평균 credit:1.48, 평균 income total: 206252.54 
#결혼해서 아파트에 사는 사람들의 평균 credit:1.53, 평균 income total: 187430.96 --> 소득이 제일 적으면서 지출은 제일 많은 사람들

#이게 맞다면 승법이형이 제시한 소득과 비례하여 신용수요가 중요하다는 가설이 옳다고 할 수 있을까??

# %%
# 평균 income total과 credit의 시각화가 필요할듯
# 외부의 데이터가 필요 할 수도...
