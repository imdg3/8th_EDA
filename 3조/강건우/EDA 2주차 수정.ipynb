# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
Train=pd.read_csv('C:\\Users\\ADMIN\\Downloads\\data_ID.csv')
Train
# Out:
#       Unnamed: 0       ID  Counts  gender  car  reality  child_num  \
# 0              0     ID-0       5     0.0  0.0      0.0          0
# 1              1     ID-1       9     0.0  0.0      1.0          1
# 2              2     ID-2       6     1.0  1.0      1.0          0
# 3              3     ID-3       2     0.0  0.0      1.0          0
# 4              4     ID-4       1     0.0  1.0      1.0          0
# ...          ...      ...     ...     ...  ...      ...        ...
# 8754        8754  ID-8754       1     0.0  0.0      0.0          0
# 8755        8755  ID-8755       1     0.0  0.0      1.0          1
# 8756        8756  ID-8756       1     0.0  1.0      0.0          0
# 8757        8757  ID-8757       1     1.0  0.0      1.0          0
# 8758        8758  ID-8758       1     0.0  0.0      0.0          0
#
#       income_total           income_type                       edu_type  ...  \
# 0         202500.0  Commercial associate               Higher education  ...
# ...

# %%
Train.describe(include='all')
# Out:
#          Unnamed: 0    ID       Counts       gender          car      reality  \
# count   8759.000000  8759  8759.000000  8759.000000  8759.000000  8759.000000
# unique          NaN  8759          NaN          NaN          NaN          NaN
# top             NaN  ID-0          NaN          NaN          NaN          NaN
# freq            NaN     1          NaN          NaN          NaN          NaN
# mean    4379.000000   NaN     3.020550     0.347528     0.367964     0.671538
# std     2528.649837   NaN     2.559819     0.476212     0.482279     0.469681
# min        0.000000   NaN     1.000000     0.000000     0.000000     0.000000
# 25%     2189.500000   NaN     1.000000     0.000000     0.000000     0.000000
# 50%     4379.000000   NaN     2.000000     0.000000     0.000000     1.000000
# 75%     6568.500000   NaN     4.000000     1.000000     1.000000     1.000000
# max     8758.000000   NaN    35.000000     1.000000     1.000000     1.000000
#
# ...

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8759 entries, 0 to 8758
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         8759 non-null   int64
#  1   ID                 8759 non-null   object
#  2   Counts             8759 non-null   int64
#  3   gender             8759 non-null   float64
#  4   car                8759 non-null   float64
#  5   reality            8759 non-null   float64
#  6   child_num          8759 non-null   int64
#  7   income_total       8759 non-null   float64
#  8   income_type        8759 non-null   object
#  9   edu_type           8759 non-null   object
#  10  family_type        8759 non-null   object
#  11  house_type         8759 non-null   object
#  12  DAYS_BIRTH         8759 non-null   int64
#  13  DAYS_EMPLOYED      8759 non-null   int64
#  14  work_phone         8759 non-null   int64
#  15  phone              8759 non-null   int64
# ...

# %%
Train.dtypes
# Out:
# Unnamed: 0             int64
# ID                    object
# Counts                 int64
# gender               float64
# car                  float64
# reality              float64
# child_num              int64
# income_total         float64
# income_type           object
# edu_type              object
# family_type           object
# house_type            object
# DAYS_BIRTH             int64
# DAYS_EMPLOYED          int64
# work_phone             int64
# phone                  int64
# email                  int64
# occyp_type            object
# family_size            int64
# income_percentile    float64
# income_quantile      float64
# credit_avg           float64
# child_num_group      float64
# dtype: object

# %%
def pltpie(label, sample):
    data = Train[Train[label] == sample]
    data_c = data['credit_avg'].value_counts()
    data_c
    plt.pie(x=data_c, labels=data_c.index, autopct='%1.1f%%')
    plt.title(label+'_'+str(sample))
    plt.show()

# %%
 pltpie('family_type', 'Married')

# %%
 pltpie('family_type', 'Single / not married')

# %%
pltpie('family_type', 'Widow')

# %%
pltpie('family_type', 'Separated')

# %%
 pltpie('house_type', 'House / apartment')

# %%
pltpie('house_type', 'Rented apartment')

# %%
Train2=Train[(Train['family_type']=='Single / not married')&(Train['house_type']=='Rented apartment')]

df=Train2.drop(['ID','Counts','gender','car','child_num','income_type','edu_type','DAYS_BIRTH','DAYS_EMPLOYED','work_phone','phone','email','occyp_type','family_size','reality','income_percentile','income_quantile','child_num_group','Unnamed: 0'], axis = 1)
df
# Out:
#       income_total           family_type        house_type  credit_avg
# 130       297000.0  Single / not married  Rented apartment    1.000000
# 177       157500.0  Single / not married  Rented apartment    1.000000
# 204       171000.0  Single / not married  Rented apartment    1.571429
# 226       292500.0  Single / not married  Rented apartment    1.142857
# 1002      112500.0  Single / not married  Rented apartment    1.272727
# 1165      180000.0  Single / not married  Rented apartment    1.333333
# 1211      157500.0  Single / not married  Rented apartment    2.000000
# 1384      171261.0  Single / not married  Rented apartment    2.000000
# 1528      144000.0  Single / not married  Rented apartment    1.800000
# 1732      540000.0  Single / not married  Rented apartment    2.000000
# 1765      495000.0  Single / not married  Rented apartment    2.000000
# 1826      157500.0  Single / not married  Rented apartment    1.666667
# ...

# %%
print(df.mean())
# Out:
# income_total    201475.730769
# credit_avg           1.414868
# dtype: float64
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15392\2807316344.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df.mean())

# %%
Train3=Train[(Train['family_type']=='Single / not married')&(Train['house_type']=='House / apartment')]

df1=Train3.drop(['ID','Counts','gender','car','child_num','income_type','edu_type','DAYS_BIRTH','DAYS_EMPLOYED','work_phone','phone','email','occyp_type','family_size','reality','income_percentile','income_quantile','child_num_group','Unnamed: 0'], axis = 1)
df1
# Out:
#       income_total           family_type         house_type  credit_avg
# 14        157500.0  Single / not married  House / apartment    2.000000
# 24        202500.0  Single / not married  House / apartment    1.428571
# 36        225000.0  Single / not married  House / apartment    1.666667
# 57        225000.0  Single / not married  House / apartment    1.466667
# 70         81000.0  Single / not married  House / apartment    1.875000
# ...            ...                   ...                ...         ...
# 8743      112500.0  Single / not married  House / apartment    2.000000
# 8747      180000.0  Single / not married  House / apartment    2.000000
# 8753      225000.0  Single / not married  House / apartment    2.000000
# 8754      225000.0  Single / not married  House / apartment    2.000000
# 8757      171000.0  Single / not married  House / apartment    2.000000
#
# [1007 rows x 4 columns]

# %%
print(df1.mean())
# Out:
# income_total    185643.294935
# credit_avg           1.546737
# dtype: float64
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15392\1183993460.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df1.mean())

# %%
Train4=Train[(Train['family_type']=='Married')&(Train['house_type']=='Rented apartment')]
df2=Train4.drop(['ID','Counts','gender','car','child_num','income_type','edu_type','DAYS_BIRTH','DAYS_EMPLOYED','work_phone','phone','email','occyp_type','family_size','reality','income_percentile','income_quantile','child_num_group','Unnamed: 0'], axis = 1)
df2
# Out:
#       income_total family_type        house_type  credit_avg
# 179       315000.0     Married  Rented apartment       1.625
# 250        90000.0     Married  Rented apartment       1.000
# 350       234000.0     Married  Rented apartment       2.000
# 355       225000.0     Married  Rented apartment       1.000
# 507       112500.0     Married  Rented apartment       2.000
# ...            ...         ...               ...         ...
# 7859      238500.0     Married  Rented apartment       2.000
# 8064      157500.0     Married  Rented apartment       1.000
# 8166     1125000.0     Married  Rented apartment       2.000
# 8238      135000.0     Married  Rented apartment       1.500
# 8538      135000.0     Married  Rented apartment       1.000
#
# [68 rows x 4 columns]

# %%
print(df2.mean())
# Out:
# income_total    202976.470588
# credit_avg           1.491830
# dtype: float64
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15392\2250652926.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df2.mean())

# %%
Train5=Train[(Train['family_type']=='Married')&(Train['house_type']=='House / apartment')]
df3=Train5.drop(['ID','Counts','gender','car','child_num','income_type','edu_type','DAYS_BIRTH','DAYS_EMPLOYED','work_phone','phone','email','occyp_type','family_size','reality','income_percentile','income_quantile','child_num_group','Unnamed: 0'], axis = 1)
df3
# Out:
#       income_total family_type         house_type  credit_avg
# 2         450000.0     Married  House / apartment    1.833333
# 3         202500.0     Married  House / apartment    1.000000
# 4         157500.0     Married  House / apartment    2.000000
# 5         270000.0     Married  House / apartment    1.000000
# 7         270000.0     Married  House / apartment    0.000000
# ...            ...         ...                ...         ...
# 8745      225000.0     Married  House / apartment    1.000000
# 8746       99000.0     Married  House / apartment    2.000000
# 8749      135000.0     Married  House / apartment    2.000000
# 8750      112500.0     Married  House / apartment    1.000000
# 8751      121500.0     Married  House / apartment    2.000000
#
# [5376 rows x 4 columns]

# %%
print(df3.mean())
# Out:
# income_total    182191.181083
# credit_avg           1.547691
# dtype: float64
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15392\392603381.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df3.mean())

# %%
#솔로이면서 임대 아파트에 사는 사람들의 평균 credit:1.414, 평균 income total: 201475.730769 --> 소득은 높으면서 지출하는 금액은 제일 적은 사람들
#솔로이면선 아파트에 사는 사람들의 평균 credit:1.546, 평균 income total:  185643.294935
#결혼해서 임대 아파트에 사는 사람들의 평균 credit:1.1.492, 평균 income total: 202976.470588
#결혼해서 아파트에 사는 사람들의 평균 credit:1.548, 평균 income total: 182191.181083 --> 소득이 제일 적으면서 지출은 제일 많은 사람들

#이게 맞다면 승법이형이 제시한 소득과 비례하여 신용수요가 중요하다는 가설이 옳다고 할 수 있을까??

#실제로 임대 아파트에 사는 사람들의 평균 소득이 더 높은 것을 확인 할 수 있음 
#결혼을 하지 않은 사람들의 평균 소득이 결혼을 한 사람의 평균 소득보다 높은 것을 확인 할 수 있음
